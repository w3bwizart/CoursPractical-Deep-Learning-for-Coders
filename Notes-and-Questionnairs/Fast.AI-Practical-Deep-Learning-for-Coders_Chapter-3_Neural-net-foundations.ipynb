# %% [markdown]
# ### Fast.AI: Practical Deep Learning for Coders: Book Chapter 3:
# # 3. Neural net foundations:
# ## XXXXXXXXX

# %% [markdown]
# ---
# # THIS BLOCK MOVES WHILE LEARNING
# I will keep links and things I need throughout the course here.
#
# ### Fast.AI
# Course: https://course.fast.ai/
#
# Book: https://drive.google.com/file/d/1L5tktNUA1r794Ds_VGUMlO7x7MyPzR6M/view?usp=drive_link
# Answers: to all these questions are also available on thebook’s  website.
#
# ### OpenPlayground
# https://github.com/nat/openplayground
#
# `openplayground run`
#
# ### OpenAI
# https://platform.openai.com/playground
# https://platform.openai.com/assistants
#
# ### Hugging Face
# https://huggingface.co/join
#
#
#
# ---
